# %% [markdown]
# # USO DI LIBRERIE PER IMPLEMENTARE ZNE SU FAKE BACKEND

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.linalg as la
import math


from qiskit import QuantumCircuit, transpile
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit.visualization import plot_histogram
from qiskit.quantum_info import SparsePauliOp, Statevector
from qiskit.primitives import StatevectorEstimator, BackendEstimatorV2 as BackendEstimator, BackendSamplerV2 as BackendSampler
from qiskit_ibm_runtime import QiskitRuntimeService
 


from qiskit_aer import AerSimulator
from qiskit_aer.noise import NoiseModel
from qiskit_aer.primitives import EstimatorV2 as Estimator
from qiskit_aer.noise import (QuantumError, depolarizing_error, amplitude_damping_error, phase_damping_error, pauli_error)
from qiskit.providers import Options

#Rendiamo generale la funzione, prende N numero di Spin, t il tempo, j il primo spin e i il secondo spin (questi saranno j e j+1 in quanto nearest neighbours)
def R_zz(N, t, j, i):
    
    ZZ_qc = QuantumCircuit(N)

    ZZ_qc.cx(j,i)
    ZZ_qc.rz(2 * t, i) #vedi definizione sopracitata per il fattore 2
    ZZ_qc.cx(j,i)

    return ZZ_qc

#decomponiamo il Rot. Gate XX
def R_xx(N, t, j, i):

    XX_qc = QuantumCircuit(N)

    XX_qc.ry(np.pi/2,[j,i])
    XX_qc.cx(j,i)
    XX_qc.rz(2 * t, i)
    XX_qc.cx(j,i)
    XX_qc.ry(-np.pi/2,[j,i])

    return XX_qc

#decomponiamo il Rot. Gate YY
def R_yy(N, t, j, i):
    YY_qc = QuantumCircuit(N)
    
    YY_qc.rx(np.pi/2,[j,i])
    YY_qc.cx(j,i)
    YY_qc.rz(2 * t, i)
    YY_qc.cx(j,i)
    YY_qc.rx(-np.pi/2,[j,i])

    return YY_qc


#definiamo l'hamiltoniana
def H_Heis(N):
    #usiamo J = 1
    XX_tuples = [("XX", [i, i + 1], 1) for i in range(0, N-1)]
    YY_tuples = [("YY", [i, i + 1], 1) for i in range(0, N-1)]
    ZZ_tuples = [("ZZ", [i, i + 1], 1) for i in range(0, N-1)]

    #col metodo from_sparse_list di SparsePauliOp definiamo l'hamiltoniana
    hamiltonian = SparsePauliOp.from_sparse_list([*XX_tuples, *YY_tuples, *ZZ_tuples], N)

    return hamiltonian

#definiamo l'evoluzione temporale nel caso classico
def U_Heis(n_spins,t):
    H = H_Heis(n_spins).to_matrix()
    return la.expm(-1j*t*H)

def Heisenberg_Trotter(num_spins, trotter_steps, t):
    #definiamo un time step dt
    dt = (t)/(trotter_steps) 

    #creiamo il quantumcircuit
    qc_t = QuantumCircuit(num_spins)

    #iteriamo su ogni time step
    for i in range(trotter_steps):
        #iteriamo su ogni spin
        for j in range(0, num_spins -1):
            #implementazione dei gate è uguale al caso precedente, in quanto operiamo su coppie di spin
            qc_t = qc_t.compose(R_xx(num_spins,dt,j,j+1))
            qc_t = qc_t.compose(R_yy(num_spins,dt,j,j+1))
            qc_t = qc_t.compose(R_zz(num_spins,dt,j,j+1))

        
        #qc.barrier()

    return qc_t


#definiamo il numero di time steps
t_steps = 63

#definiamo il tempo in cui facciamo evolvere il sistema
dt = np.pi

#generiamo una spaziatura lineare di t_steps nell'intervallo [0, pi]
ts = np.linspace(0, dt, t_steps) 

initial_state = Statevector.from_label('011').data
probs_110 = [np.abs((initial_state @ U_Heis(3,float(t)) @ initial_state))**2 for t in ts]

# %%
#pip install mitiq[qiskit]
from mitiq import zne
from mitiq import rem
from mitiq.zne import execute_with_zne
from mitiq.zne.scaling import (
    fold_gates_at_random,
    fold_global,
    fold_all
)
from mitiq.zne.inference import LinearFactory, RichardsonFactory
from mitiq import (
    Calibrator,
    Settings,
    execute_with_mitigation,
    MeasurementResult,
)


from qiskit_ibm_runtime.fake_provider import FakeManilaV2
QiskitRuntimeService.save_account(channel="ibm_quantum", token="982082508a1c98ca02cb712c6751b42ef860d905b080b3bfc02ef35d68d84441803586912cbcf181e1e72ebc8569103421b06c25408fe8134975a72575c4d637", overwrite= True)


def execute_circuit(circuit):
    
    prj_zero = SparsePauliOp.from_list([("I", 1/2), ("Z", 1/2)])
    prj_one = SparsePauliOp.from_list([("I", 1/2), ("Z", -1/2)])
    prj = prj_one ^ prj_one ^ prj_zero
    
    isa_circuit = pm.run(circuit)
    isa_observable = prj.apply_layout(isa_circuit.layout)
    print("isa applied")
    trotter_result = estimator.run([(isa_circuit, isa_observable)]).result()
    print("circuito runnato")
    trotter_value = trotter_result[0].data.evs
    trotter_expectation_value = trotter_value.mean().real
    print(str(trotter_expectation_value) + "\n")
    return trotter_expectation_value

# %%
fake_backend = FakeManilaV2()
noise_model = NoiseModel.from_backend(fake_backend)
simulator = AerSimulator(noise_model=noise_model)
estimator = BackendEstimator(backend=simulator)
pm = generate_preset_pass_manager(optimization_level=0)

    
prj_zero = SparsePauliOp.from_list([("I", 1/2), ("Z", 1/2)])
prj_one = SparsePauliOp.from_list([("I", 1/2), ("Z", -1/2)])
prj = prj_one ^ prj_one ^ prj_zero

probs_110_zne = []
probs_110_trotter = []

for sim_t in ts:
    qc = QuantumCircuit(3)
    #buildiamo lo stato
    qc.x(1)
    qc.x(2)
        
    trott_steps = Heisenberg_Trotter(num_spins=3,trotter_steps=12,t=sim_t)
        
    qc = qc.compose(trott_steps)


    trotter_expectation_value = execute_with_zne(qc, execute_circuit, factory=LinearFactory([1.0, 1.5, 2.0, 2.5, 3.0]), scale_noise=zne.scaling.fold_global)
    trotter = execute_circuit(qc)


    probs_110_trotter.append(trotter)
    probs_110_zne.append(trotter_expectation_value)

    
    print(str(sim_t) + " completed\n")
# Out:
# isa applied
# circuito runnato
# 0.202392578125
#
# isa applied
# circuito runnato
# 0.14599609375
#
# isa applied
# circuito runnato
# 0.124267578125
#
# isa applied
# circuito runnato
# 0.11572265625
#
# isa applied
# circuito runnato
# 0.103759765625
#
# isa applied
# circuito runnato
# 0.203125
#
# 0.0 completed
#
# isa applied
# circuito runnato
# 0.2021484375
#
# isa applied
# circuito runnato
# 0.158203125
#
# isa applied
# circuito runnato
# 0.126953125
#
# isa applied
# circuito runnato
# 0.1123046875
#
# isa applied
# circuito runnato
# 0.10791015625
#
# isa applied
# circuito runnato
# 0.204833984375
#
# 0.050670849251448276 completed
#
# isa applied
# circuito runnato
# 0.199951171875
#
# isa applied
# circuito runnato
# 0.148681640625
#
# isa applied
# circuito runnato
# 0.130126953125
#
# isa applied
# circuito runnato
# 0.114990234375
#
# isa applied
# circuito runnato
# 0.111328125
#
# isa applied
# circuito runnato
# 0.208251953125
#
# 0.10134169850289655 completed
#
# isa applied
# circuito runnato
# 0.20166015625
#
# isa applied
# circuito runnato
# 0.1474609375
#
# isa applied
# circuito runnato
# 0.120361328125
#
# isa applied
# circuito runnato
# 0.1162109375
#
# isa applied
# circuito runnato
# 0.10595703125
#
# isa applied
# circuito runnato
# 0.197265625
#
# 0.15201254775434483 completed
#
# isa applied
# circuito runnato
# 0.186279296875
#
# isa applied
# circuito runnato
# 0.144775390625
#
# isa applied
# circuito runnato
# 0.1201171875
#
# isa applied
# circuito runnato
# 0.109375
#
# isa applied
# circuito runnato
# 0.10693359375
#
# isa applied
# circuito runnato
# 0.189208984375
#
# 0.2026833970057931 completed
#
# isa applied
# circuito runnato
# 0.1884765625
#
# isa applied
# circuito runnato
# 0.1337890625
#
# isa applied
# circuito runnato
# 0.117919921875
#
# isa applied
# circuito runnato
# 0.11572265625
#
# isa applied
# circuito runnato
# 0.1201171875
#
# isa applied
# circuito runnato
# 0.19677734375
#
# 0.2533542462572414 completed
#
# isa applied
# circuito runnato
# 0.195556640625
#
# isa applied
# circuito runnato
# 0.1279296875
#
# isa applied
# circuito runnato
# 0.129638671875
#
# isa applied
# circuito runnato
# 0.113525390625
#
# isa applied
# circuito runnato
# 0.10693359375
#
# isa applied
# circuito runnato
# 0.186279296875
#
# 0.30402509550868967 completed
#
# isa applied
# circuito runnato
# 0.188720703125
#
# isa applied
# circuito runnato
# 0.139404296875
#
# isa applied
# circuito runnato
# 0.1328125
#
# isa applied
# circuito runnato
# 0.114013671875
#
# isa applied
# circuito runnato
# 0.110107421875
#
# isa applied
# circuito runnato
# 0.176025390625
#
# 0.35469594476013794 completed
#
# isa applied
# circuito runnato
# 0.18017578125
#
# isa applied
# circuito runnato
# 0.140380859375
#
# isa applied
# circuito runnato
# 0.127685546875
#
# isa applied
# circuito runnato
# 0.11474609375
#
# isa applied
# circuito runnato
# 0.101806640625
#
# isa applied
# circuito runnato
# 0.17333984375
#
# 0.4053667940115862 completed
#
# isa applied
# circuito runnato
# 0.1748046875
#
# isa applied
# circuito runnato
# 0.127197265625
#
# isa applied
# circuito runnato
# 0.12939453125
#
# isa applied
# circuito runnato
# 0.11376953125
#
# isa applied
# circuito runnato
# 0.108642578125
#
# isa applied
# circuito runnato
# 0.17333984375
#
# 0.4560376432630345 completed
#
# isa applied
# circuito runnato
# 0.16455078125
#
# isa applied
# circuito runnato
# 0.1298828125
#
# isa applied
# circuito runnato
# 0.120849609375
#
# isa applied
# circuito runnato
# 0.10205078125
#
# isa applied
# circuito runnato
# 0.11328125
#
# isa applied
# circuito runnato
# 0.166015625
#
# 0.5067084925144828 completed
#
# isa applied
# circuito runnato
# 0.16796875
#
# isa applied
# circuito runnato
# 0.1337890625
#
# isa applied
# circuito runnato
# 0.11767578125
#
# isa applied
# circuito runnato
# 0.11279296875
#
# isa applied
# circuito runnato
# 0.114501953125
#
# isa applied
# circuito runnato
# 0.172119140625
#
# 0.5573793417659311 completed
#
# isa applied
# circuito runnato
# 0.1669921875
#
# isa applied
# circuito runnato
# 0.12548828125
#
# isa applied
# circuito runnato
# 0.1171875
#
# isa applied
# circuito runnato
# 0.114990234375
#
# isa applied
# circuito runnato
# 0.107666015625
#
# isa applied
# circuito runnato
# 0.160400390625
#
# 0.6080501910173793 completed
#
# isa applied
# circuito runnato
# 0.147705078125
#
# isa applied
# circuito runnato
# 0.135009765625
#
# isa applied
# circuito runnato
# 0.126220703125
#
# isa applied
# circuito runnato
# 0.1123046875
#
# isa applied
# circuito runnato
# 0.109619140625
#
# isa applied
# circuito runnato
# 0.1474609375
#
# 0.6587210402688276 completed
#
# isa applied
# circuito runnato
# 0.154296875
#
# isa applied
# circuito runnato
# 0.122802734375
#
# isa applied
# circuito runnato
# 0.1220703125
#
# isa applied
# circuito runnato
# 0.110595703125
#
# isa applied
# circuito runnato
# 0.103271484375
#
# isa applied
# circuito runnato
# 0.15869140625
#
# 0.7093918895202759 completed
#
# isa applied
# circuito runnato
# 0.1455078125
#
# isa applied
# circuito runnato
# 0.130615234375
#
# isa applied
# circuito runnato
# 0.107177734375
#
# isa applied
# circuito runnato
# 0.110595703125
#
# isa applied
# circuito runnato
# 0.104736328125
#
# isa applied
# circuito runnato
# 0.140380859375
#
# 0.7600627387717241 completed
#
# isa applied
# circuito runnato
# 0.146240234375
#
# isa applied
# circuito runnato
# 0.130859375
#
# isa applied
# circuito runnato
# 0.1142578125
#
# isa applied
# circuito runnato
# 0.10791015625
#
# isa applied
# circuito runnato
# 0.10107421875
#
# isa applied
# circuito runnato
# 0.1474609375
#
# 0.8107335880231724 completed
#
# isa applied
# circuito runnato
# 0.134033203125
#
# isa applied
# circuito runnato
# 0.11328125
#
# isa applied
# circuito runnato
# 0.115478515625
#
# isa applied
# circuito runnato
# 0.115234375
#
# isa applied
# circuito runnato
# 0.10888671875
#
# isa applied
# circuito runnato
# 0.14306640625
#
# 0.8614044372746207 completed
#
# isa applied
# circuito runnato
# 0.138916015625
#
# isa applied
# circuito runnato
# 0.120361328125
#
# isa applied
# circuito runnato
# 0.11865234375
#
# isa applied
# circuito runnato
# 0.11376953125
#
# isa applied
# circuito runnato
# 0.1171875
#
# isa applied
# circuito runnato
# 0.13525390625
#
# 0.912075286526069 completed
#
# isa applied
# circuito runnato
# 0.13427734375
#
# isa applied
# circuito runnato
# 0.116455078125
#
# isa applied
# circuito runnato
# 0.12109375
#
# isa applied
# circuito runnato
# 0.112060546875
#
# isa applied
# circuito runnato
# 0.121337890625
#
# isa applied
# circuito runnato
# 0.125
#
# 0.9627461357775172 completed
#
# isa applied
# circuito runnato
# 0.130615234375
#
# isa applied
# circuito runnato
# 0.124755859375
#
# isa applied
# circuito runnato
# 0.115966796875
#
# isa applied
# circuito runnato
# 0.117431640625
#
# isa applied
# circuito runnato
# 0.115234375
#
# isa applied
# circuito runnato
# 0.144287109375
#
# 1.0134169850289656 completed
#
# isa applied
# circuito runnato
# 0.130859375
#
# isa applied
# circuito runnato
# 0.12255859375
#
# isa applied
# circuito runnato
# 0.11767578125
#
# isa applied
# circuito runnato
# 0.116943359375
#
# isa applied
# circuito runnato
# 0.10400390625
#
# isa applied
# circuito runnato
# 0.12890625
#
# 1.0640878342804139 completed
#
# isa applied
# circuito runnato
# 0.115234375
#
# isa applied
# circuito runnato
# 0.123046875
#
# isa applied
# circuito runnato
# 0.1123046875
#
# isa applied
# circuito runnato
# 0.110107421875
#
# isa applied
# circuito runnato
# 0.102294921875
#
# isa applied
# circuito runnato
# 0.13037109375
#
# 1.1147586835318621 completed
#
# isa applied
# circuito runnato
# 0.125732421875
#
# isa applied
# circuito runnato
# 0.118896484375
#
# isa applied
# circuito runnato
# 0.113037109375
#
# isa applied
# circuito runnato
# 0.116455078125
#
# isa applied
# circuito runnato
# 0.107666015625
#
# isa applied
# circuito runnato
# 0.113525390625
#
# 1.1654295327833104 completed
#
# isa applied
# circuito runnato
# 0.134765625
#
# isa applied
# circuito runnato
# 0.1142578125
#
# isa applied
# circuito runnato
# 0.106689453125
#
# isa applied
# circuito runnato
# 0.104736328125
#
# isa applied
# circuito runnato
# 0.110595703125
#
# isa applied
# circuito runnato
# 0.118896484375
#
# 1.2161003820347587 completed
#
# isa applied
# circuito runnato
# 0.125732421875
#
# isa applied
# circuito runnato
# 0.12353515625
#
# isa applied
# circuito runnato
# 0.10595703125
#
# isa applied
# circuito runnato
# 0.1142578125
#
# isa applied
# circuito runnato
# 0.11181640625
#
# isa applied
# circuito runnato
# 0.118408203125
#
# 1.266771231286207 completed
#
# isa applied
# circuito runnato
# 0.125244140625
#
# isa applied
# circuito runnato
# 0.11279296875
#
# isa applied
# circuito runnato
# 0.11865234375
#
# isa applied
# circuito runnato
# 0.106201171875
#
# isa applied
# circuito runnato
# 0.10986328125
#
# isa applied
# circuito runnato
# 0.12255859375
#
# 1.3174420805376552 completed
#
# isa applied
# circuito runnato
# 0.116455078125
#
# isa applied
# circuito runnato
# 0.112060546875
#
# isa applied
# circuito runnato
# 0.114990234375
#
# isa applied
# circuito runnato
# 0.111328125
#
# isa applied
# circuito runnato
# 0.111572265625
#
# isa applied
# circuito runnato
# 0.1162109375
#
# 1.3681129297891035 completed
#
# isa applied
# circuito runnato
# 0.12060546875
#
# isa applied
# circuito runnato
# 0.115478515625
#
# isa applied
# circuito runnato
# 0.12939453125
#
# isa applied
# circuito runnato
# 0.111328125
#
# isa applied
# circuito runnato
# 0.111572265625
#
# isa applied
# circuito runnato
# 0.11328125
#
# 1.4187837790405518 completed
#
# isa applied
# circuito runnato
# 0.125732421875
#
# isa applied
# circuito runnato
# 0.120361328125
#
# isa applied
# circuito runnato
# 0.11669921875
#
# isa applied
# circuito runnato
# 0.115478515625
#
# isa applied
# circuito runnato
# 0.10888671875
#
# isa applied
# circuito runnato
# 0.11572265625
#
# 1.469454628292 completed
#
# isa applied
# circuito runnato
# 0.11279296875
#
# isa applied
# circuito runnato
# 0.11181640625
#
# isa applied
# circuito runnato
# 0.11669921875
#
# isa applied
# circuito runnato
# 0.105224609375
#
# isa applied
# circuito runnato
# 0.115234375
#
# isa applied
# circuito runnato
# 0.1162109375
#
# 1.5201254775434483 completed
#
# isa applied
# circuito runnato
# 0.116455078125
#
# isa applied
# circuito runnato
# 0.112548828125
#
# isa applied
# circuito runnato
# 0.117919921875
#
# isa applied
# circuito runnato
# 0.10302734375
#
# isa applied
# circuito runnato
# 0.112060546875
#
# isa applied
# circuito runnato
# 0.120849609375
#
# 1.5707963267948966 completed
#
# isa applied
# circuito runnato
# 0.1171875
#
# isa applied
# circuito runnato
# 0.11279296875
#
# isa applied
# circuito runnato
# 0.115234375
#
# isa applied
# circuito runnato
# 0.1083984375
#
# isa applied
# circuito runnato
# 0.1181640625
#
# isa applied
# circuito runnato
# 0.11474609375
#
# 1.6214671760463448 completed
#
# isa applied
# circuito runnato
# 0.124755859375
#
# isa applied
# circuito runnato
# 0.113037109375
#
# isa applied
# circuito runnato
# 0.115478515625
#
# isa applied
# circuito runnato
# 0.1083984375
#
# isa applied
# circuito runnato
# 0.109375
#
# isa applied
# circuito runnato
# 0.119384765625
#
# 1.672138025297793 completed
#
# isa applied
# circuito runnato
# 0.1240234375
#
# isa applied
# circuito runnato
# 0.113525390625
#
# isa applied
# circuito runnato
# 0.107177734375
#
# isa applied
# circuito runnato
# 0.11328125
#
# isa applied
# circuito runnato
# 0.10986328125
#
# isa applied
# circuito runnato
# 0.117919921875
#
# 1.7228088745492414 completed
#
# isa applied
# circuito runnato
# 0.12451171875
#
# isa applied
# circuito runnato
# 0.112060546875
#
# isa applied
# circuito runnato
# 0.115478515625
#
# isa applied
# circuito runnato
# 0.1201171875
#
# isa applied
# circuito runnato
# 0.115478515625
#
# isa applied
# circuito runnato
# 0.122802734375
#
# 1.7734797238006896 completed
#
# isa applied
# circuito runnato
# 0.12060546875
#
# isa applied
# circuito runnato
# 0.118408203125
#
# isa applied
# circuito runnato
# 0.114990234375
#
# isa applied
# circuito runnato
# 0.109130859375
#
# isa applied
# circuito runnato
# 0.103515625
#
# isa applied
# circuito runnato
# 0.130859375
#
# 1.824150573052138 completed
#
# isa applied
# circuito runnato
# 0.13037109375
#
# isa applied
# circuito runnato
# 0.1142578125
#
# isa applied
# circuito runnato
# 0.106689453125
#
# isa applied
# circuito runnato
# 0.117919921875
#
# isa applied
# circuito runnato
# 0.119140625
#
# isa applied
# circuito runnato
# 0.125244140625
#
# 1.8748214223035862 completed
#
# isa applied
# circuito runnato
# 0.1328125
#
# isa applied
# circuito runnato
# 0.1220703125
#
# isa applied
# circuito runnato
# 0.118896484375
#
# isa applied
# circuito runnato
# 0.106201171875
#
# isa applied
# circuito runnato
# 0.1171875
#
# isa applied
# circuito runnato
# 0.13427734375
#
# 1.9254922715550344 completed
#
# isa applied
# circuito runnato
# 0.12353515625
#
# isa applied
# circuito runnato
# 0.1123046875
#
# isa applied
# circuito runnato
# 0.101318359375
#
# isa applied
# circuito runnato
# 0.10986328125
#
# isa applied
# circuito runnato
# 0.111572265625
#
# isa applied
# circuito runnato
# 0.117919921875
#
# 1.9761631208064827 completed
#
# isa applied
# circuito runnato
# 0.1337890625
#
# isa applied
# circuito runnato
# 0.1044921875
#
# isa applied
# circuito runnato
# 0.119384765625
#
# isa applied
# circuito runnato
# 0.109375
#
# isa applied
# circuito runnato
# 0.112060546875
#
# isa applied
# circuito runnato
# 0.13623046875
#
# 2.026833970057931 completed
#
# isa applied
# circuito runnato
# 0.1279296875
#
# isa applied
# circuito runnato
# 0.112060546875
#
# isa applied
# circuito runnato
# 0.112060546875
#
# isa applied
# circuito runnato
# 0.1142578125
#
# isa applied
# circuito runnato
# 0.113037109375
#
# isa applied
# circuito runnato
# 0.1279296875
#
# 2.0775048193093792 completed
#
# isa applied
# circuito runnato
# 0.135498046875
#
# isa applied
# circuito runnato
# 0.126708984375
#
# isa applied
# circuito runnato
# 0.117431640625
#
# isa applied
# circuito runnato
# 0.106689453125
#
# isa applied
# circuito runnato
# 0.114990234375
#
# isa applied
# circuito runnato
# 0.134521484375
#
# 2.1281756685608277 completed
#
# isa applied
# circuito runnato
# 0.138916015625
#
# isa applied
# circuito runnato
# 0.121826171875
#
# isa applied
# circuito runnato
# 0.120361328125
#
# isa applied
# circuito runnato
# 0.10595703125
#
# isa applied
# circuito runnato
# 0.108642578125
#
# isa applied
# circuito runnato
# 0.133056640625
#
# 2.178846517812276 completed
#
# isa applied
# circuito runnato
# 0.126708984375
#
# isa applied
# circuito runnato
# 0.115478515625
#
# isa applied
# circuito runnato
# 0.113037109375
#
# isa applied
# circuito runnato
# 0.11474609375
#
# isa applied
# circuito runnato
# 0.110107421875
#
# isa applied
# circuito runnato
# 0.12158203125
#
# 2.2295173670637243 completed
#
# isa applied
# circuito runnato
# 0.126220703125
#
# isa applied
# circuito runnato
# 0.116943359375
#
# isa applied
# circuito runnato
# 0.1240234375
#
# isa applied
# circuito runnato
# 0.1240234375
#
# isa applied
# circuito runnato
# 0.115478515625
#
# isa applied
# circuito runnato
# 0.128173828125
#
# 2.2801882163151723 completed
#
# isa applied
# circuito runnato
# 0.1279296875
#
# isa applied
# circuito runnato
# 0.12353515625
#
# isa applied
# circuito runnato
# 0.118408203125
#
# isa applied
# circuito runnato
# 0.114013671875
#
# isa applied
# circuito runnato
# 0.111083984375
#
# isa applied
# circuito runnato
# 0.123046875
#
# 2.330859065566621 completed
#
# isa applied
# circuito runnato
# 0.122802734375
#
# isa applied
# circuito runnato
# 0.11865234375
#
# isa applied
# circuito runnato
# 0.114990234375
#
# isa applied
# circuito runnato
# 0.1181640625
#
# isa applied
# circuito runnato
# 0.115234375
#
# isa applied
# circuito runnato
# 0.1240234375
#
# 2.381529914818069 completed
#
# isa applied
# circuito runnato
# 0.119384765625
#
# isa applied
# circuito runnato
# 0.11181640625
#
# isa applied
# circuito runnato
# 0.114501953125
#
# isa applied
# circuito runnato
# 0.114501953125
#
# isa applied
# circuito runnato
# 0.107421875
#
# isa applied
# circuito runnato
# 0.1171875
#
# 2.4322007640695174 completed
#
# isa applied
# circuito runnato
# 0.121337890625
#
# isa applied
# circuito runnato
# 0.123291015625
#
# isa applied
# circuito runnato
# 0.106201171875
#
# isa applied
# circuito runnato
# 0.113525390625
#
# isa applied
# circuito runnato
# 0.109375
#
# isa applied
# circuito runnato
# 0.1162109375
#
# 2.4828716133209654 completed
#
# isa applied
# circuito runnato
# 0.1181640625
#
# isa applied
# circuito runnato
# 0.117431640625
#
# isa applied
# circuito runnato
# 0.11669921875
#
# isa applied
# circuito runnato
# 0.114990234375
#
# isa applied
# circuito runnato
# 0.10888671875
#
# isa applied
# circuito runnato
# 0.128662109375
#
# 2.533542462572414 completed
#
# isa applied
# circuito runnato
# 0.125732421875
#
# isa applied
# circuito runnato
# 0.1259765625
#
# isa applied
# circuito runnato
# 0.115966796875
#
# isa applied
# circuito runnato
# 0.117919921875
#
# isa applied
# circuito runnato
# 0.107177734375
#
# isa applied
# circuito runnato
# 0.128173828125
#
# 2.584213311823862 completed
#
# isa applied
# circuito runnato
# 0.125244140625
#
# isa applied
# circuito runnato
# 0.11962890625
#
# isa applied
# circuito runnato
# 0.114013671875
#
# isa applied
# circuito runnato
# 0.109619140625
#
# isa applied
# circuito runnato
# 0.1171875
#
# isa applied
# circuito runnato
# 0.121826171875
#
# 2.6348841610753104 completed
#
# isa applied
# circuito runnato
# 0.129638671875
#
# isa applied
# circuito runnato
# 0.12060546875
#
# isa applied
# circuito runnato
# 0.1142578125
#
# isa applied
# circuito runnato
# 0.103271484375
#
# isa applied
# circuito runnato
# 0.114501953125
#
# isa applied
# circuito runnato
# 0.1337890625
#
# 2.6855550103267585 completed
#
# isa applied
# circuito runnato
# 0.127197265625
#
# isa applied
# circuito runnato
# 0.11865234375
#
# isa applied
# circuito runnato
# 0.113037109375
#
# isa applied
# circuito runnato
# 0.114013671875
#
# isa applied
# circuito runnato
# 0.1025390625
#
# isa applied
# circuito runnato
# 0.12548828125
#
# 2.736225859578207 completed
#
# isa applied
# circuito runnato
# 0.12939453125
#
# isa applied
# circuito runnato
# 0.114990234375
#
# isa applied
# circuito runnato
# 0.11376953125
#
# isa applied
# circuito runnato
# 0.1171875
#
# isa applied
# circuito runnato
# 0.109619140625
#
# isa applied
# circuito runnato
# 0.12451171875
#
# 2.786896708829655 completed
#
# isa applied
# circuito runnato
# 0.13427734375
#
# isa applied
# circuito runnato
# 0.12109375
#
# isa applied
# circuito runnato
# 0.1123046875
#
# isa applied
# circuito runnato
# 0.109375
#
# isa applied
# circuito runnato
# 0.108154296875
#
# isa applied
# circuito runnato
# 0.1337890625
#
# 2.8375675580811035 completed
#
# isa applied
# circuito runnato
# 0.13232421875
#
# isa applied
# circuito runnato
# 0.126708984375
#
# isa applied
# circuito runnato
# 0.115966796875
#
# isa applied
# circuito runnato
# 0.11083984375
#
# isa applied
# circuito runnato
# 0.119140625
#
# isa applied
# circuito runnato
# 0.143310546875
#
# 2.8882384073325515 completed
#
# isa applied
# circuito runnato
# 0.13134765625
#
# isa applied
# circuito runnato
# 0.1181640625
#
# isa applied
# circuito runnato
# 0.1181640625
#
# isa applied
# circuito runnato
# 0.111572265625
#
# isa applied
# circuito runnato
# 0.112060546875
#
# isa applied
# circuito runnato
# 0.139892578125
#
# 2.938909256584 completed
#
# isa applied
# circuito runnato
# 0.13037109375
#
# isa applied
# circuito runnato
# 0.11572265625
#
# isa applied
# circuito runnato
# 0.102783203125
#
# isa applied
# circuito runnato
# 0.109130859375
#
# isa applied
# circuito runnato
# 0.11474609375
#
# isa applied
# circuito runnato
# 0.139404296875
#
# 2.989580105835448 completed
#
# isa applied
# circuito runnato
# 0.1376953125
#
# isa applied
# circuito runnato
# 0.12548828125
#
# isa applied
# circuito runnato
# 0.115966796875
#
# isa applied
# circuito runnato
# 0.111083984375
#
# isa applied
# circuito runnato
# 0.113037109375
#
# isa applied
# circuito runnato
# 0.146240234375
#
# 3.0402509550868966 completed
#
# isa applied
# circuito runnato
# 0.149169921875
#
# isa applied
# circuito runnato
# 0.11865234375
#
# isa applied
# circuito runnato
# 0.109130859375
#
# isa applied
# circuito runnato
# 0.11083984375
#
# isa applied
# circuito runnato
# 0.1181640625
#
# isa applied
# circuito runnato
# 0.141357421875
#
# 3.0909218043383446 completed
#
# isa applied
# circuito runnato
# 0.135986328125
#
# isa applied
# circuito runnato
# 0.125
#
# isa applied
# circuito runnato
# 0.12255859375
#
# isa applied
# circuito runnato
# 0.119873046875
#
# isa applied
# circuito runnato
# 0.115478515625
#
# isa applied
# circuito runnato
# 0.144287109375
#
# 3.141592653589793 completed

# %%
#plottiamo
plt.plot(ts, probs_110,linestyle="dashed",color="black",label="Esatta")
plt.plot(ts, probs_110_zne,label= "ZNE")
plt.plot(ts, probs_110_trotter,label= "Trotter")
plt.xlabel('t')
plt.ylabel(r'probabilità dello stato $|110\rangle$')
plt.title(r'Confronto con ZNE applicata tramite libreria mitiq')
plt.legend()
plt.grid()
plt.savefig('../../png/zne_mitiq.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #plottiamo
# ----> 2 plt.plot(ts, probs_110,linestyle="dashed",color="black",label="Esatta")
#       3 plt.plot(ts, probs_110_zne,label= "ZNE")
#       4 plt.plot(ts, probs_110_trotter,label= "Trotter")
#
# NameError: name 'plt' is not defined
